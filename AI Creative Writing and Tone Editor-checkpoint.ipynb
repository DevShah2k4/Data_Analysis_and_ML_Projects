# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-genai
# Out:
# ...
#      -------------------------------------- 241.5/241.5 kB 3.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 109.1/109.1 kB 6.6 MB/s eta 0:00:00
# ...
#      ------------------------------------- 176.8/176.8 kB 11.1 MB/s eta 0:00:00
# ...
#      ------------------------------------- 223.1/223.1 kB 13.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 73.5/73.5 kB 4.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.8/78.8 kB 4.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: h11
#     Found existing installation: h11 0.9.0
#     Uninstalling h11-0.9.0:
#       Successfully uninstalled h11-0.9.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.9.1
#     Uninstalling httpcore-0.9.1:
#       Successfully uninstalled httpcore-0.9.1
# ...

# %%
pip install streamlit
# Out:
# ...
#
# ...
#      ---------------------------------------- 10.1/10.1 MB 5.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 26.2/26.2 MB 4.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 208.2/208.2 kB 3.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 731.2/731.2 kB 2.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.9/6.9 MB 5.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 419.6/419.6 kB 6.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 62.8/62.8 kB ? eta 0:00:00
# ...

# %%
user_input = input("Enter Prompt:-")
# Out:
# Enter Prompt:-Write a marketing pitch for a new AI-powered vacuum cleaner

# %%
from google import genai
import pandas as pd
client = genai.Client(api_key="AIzaSyC_veJsVHRBWCwAHz0YdFo50M3vli_WEz8")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=user_input,
)
original_draft = response.text

# %%
#here in above cell the original response from AI is stored in original draft without tone means simple

# %%
#cretaed the chat using the gemni 2.5 flash model using chats module
chat = client.chats.create(model="gemini-2.5-flash")

# %%
#Taking the Revise Prompt from the user
revise_prompt = input("Enter Revise Prompt:-")
revise_response = chat.send_message(revise_prompt)
revised_draft = revise_response.text
# Out:
# Enter Revise Prompt:-Revise that pitch to sound more academic and add three bullet points.

# %%
print("==========ORIGINAL PITCH==========\n",original_draft)
print("==========REVISED PITCH===========\n",revised_draft)
# Out:
# ==========ORIGINAL PITCH==========
#  ## The Future of Clean Has Arrived. Effortlessly.
#
# **(Visual: Start with a shot of a busy, slightly stressed person looking around their home. Cut to a pristine, calm home, then reveal a sleek, quiet vacuum gliding effortlessly.)**
#
# **Voiceover/Presenter:**
# "Are you tired of the endless battle against dust, dirt, and pet hair? Do you dream of a home that's always impeccably clean, without lifting a finger or constantly monitoring a robot that gets stuck under the sofa?"
#
# "Well, stop dreaming. The future of home cleaning is here."
#
# **(Reveal the sleek AI vacuum, perhaps with a soft glow or subtle animation highlighting its smart features.)**
#
# "Introducing **[Product Name: e.g., AuraClean, SynapseClean, Helix AI]** – the revolutionary AI-powered vacuum cleaner that doesn't just clean, it *thinks*."
#
# **What makes [Product Name] different?**
#
# ...
