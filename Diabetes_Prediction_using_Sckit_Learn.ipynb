# %% [markdown]
# <a href="https://colab.research.google.com/github/DevShah2k4/Data_Analysis_and_ML_Projects/blob/main/Diabetes_Prediction_using_Sckit_Learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diabetes = pd.read_csv("/content/drive/MyDrive/DataSet/diabetes.csv")

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#Here Showing first 10 rows
diabetes.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
#Here Showing last 10 rows
diabetes.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
#Here Information is Shown
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#Here Shows the Statiscal Mesaure of Data
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Checking Null Values
diabetes.isnull()
#Reeturn True if Null Values are there
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
print("Mean Glucose value is  ",diabetes["Glucose"].mean())
# Out:
# Mean Glucose value is   120.89453125

# %%
print("Mean BMI Value is ",diabetes["BMI"].mean())
# Out:
# Mean BMI Value is  31.992578124999998

# %%
print("Mean Age is ",int(diabetes["Age"].mean()))
# Out:
# Mean Age is  33

# %%
print("Mean Insulin Value is :",diabetes["Insulin"].mean())
# Out:
# Mean Insulin Value is : 79.79947916666667

# %%
print("DiabetesPedigreeFunction :",diabetes["DiabetesPedigreeFunction"].mean())
# Out:
# DiabetesPedigreeFunction : 0.47187630208333325

# %%
#Here Pregnancies and DiabetesPedigreeFunction has no correlation between them
plt.scatter(diabetes["Pregnancies"],diabetes["DiabetesPedigreeFunction"])

# %%
plt.scatter(diabetes["Glucose"],diabetes["DiabetesPedigreeFunction"])

# %%
plt.scatter(diabetes["BloodPressure"],diabetes["DiabetesPedigreeFunction"])

# %%
#With the help of corr method we can show the correlation of each and every feature with another feature
diabetes.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
#No Correlation  between BloodPressure and Glucose
plt.scatter(diabetes["BloodPressure"],diabetes["Glucose"])

# %%
sns.countplot(x=diabetes["Outcome"])
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split

# %%
x = diabetes[["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age"]]
y = diabetes["Outcome"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lreg = LogisticRegression(random_state=42)

# %%
lreg.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
y_pred = lreg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("Test Data Accuracy Score =",accuracy_score(y_test,y_pred))
# Out:
# Test Data Accuracy Score = 0.7402597402597403

# %%
from sklearn.metrics import confusion_matrix
print("Confusion Matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Confusion Matrix :
#  [[121  30]
#  [ 30  50]]

# %%
from sklearn.metrics import classification_report
print("Classification Report :\n",classification_report(y_test,y_pred))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       151
#            1       0.62      0.62      0.62        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.71      0.71       231
# weighted avg       0.74      0.74      0.74       231

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),cmap="coolwarm",annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
clf = DecisionTreeClassifier(max_depth=4,min_samples_leaf=2,min_samples_split=2,random_state=42)

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_leaf=2, random_state=42)

# %%
yt_predict = clf.predict(x_test)

# %%
print("Confusion Matrix\n",confusion_matrix(yt_predict,y_test))
# Out:
# Confusion Matrix
#  [[104  18]
#  [ 47  62]]

# %%
#Ploting the tree
plt.figure(figsize=(10,8))
plot_tree(clf)
plt.show()

# %%
plt.figure(figsize=(12,10))
feature = clf.feature_importances_
plt.bar(x.columns,feature)
plt.title("Features vs Their Importances")
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print("Classfication Report :\n",classification_report(y_test,yt_predict))
print("Accuracy Score: = ",accuracy_score(yt_predict,y_test))
# Out:
# Classfication Report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.69      0.76       151
#            1       0.57      0.78      0.66        80
#
#     accuracy                           0.72       231
#    macro avg       0.71      0.73      0.71       231
# weighted avg       0.75      0.72      0.73       231
#
# Accuracy Score: =  0.7186147186147186

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#Model Tuning with the help of n_Estimatore and max_depth
rfc = RandomForestClassifier(n_estimators=100,max_depth=4,random_state=42)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=4, random_state=42)

# %%
rt_pred = rfc.predict(x_test)

# %%
from sklearn.metrics import classification_report,accuracy_score

# %%
print("Classification Report :\n",classification_report(y_test,rt_pred))
print("Accuracy Score: = ",accuracy_score(rt_pred,y_test))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       151
#            1       0.67      0.57      0.62        80
#
#     accuracy                           0.75       231
#    macro avg       0.73      0.71      0.72       231
# weighted avg       0.75      0.75      0.75       231
#
# Accuracy Score: =  0.7532467532467533

# %%
sns.heatmap(confusion_matrix(rt_pred,y_test),cmap="coolwarm",annot=True)
# Out:
# <Axes: >

# %%
features = rfc.feature_importances_
plt.figure(figsize=(12,10))
plt.bar(x.columns,features)
plt.title("Features vs Their Importances")
plt.show()

# %%
#pip install xgboost

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(n_estimators=100,max_depth=4,learning_rate=0.2,random_state=42)

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb.predict(x_test)

# %%
print("Classification Report = \n",classification_report(y_pred_xgb,y_test))
print("Accuracy Score =",accuracy_score(y_pred_xgb,y_test))
# Out:
# Classification Report =
#                precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77       139
#            1       0.66      0.58      0.62        92
#
#     accuracy                           0.71       231
#    macro avg       0.70      0.69      0.69       231
# weighted avg       0.71      0.71      0.71       231
#
# Accuracy Score = 0.7142857142857143

# %%
sns.heatmap(confusion_matrix(y_pred_xgb,y_test),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
model_names = ["Logistic Regression","Decision Tree Classifier","Random Forest Classifier","XGBoost"]
model_performance = [accuracy_score(y_test,y_pred),accuracy_score(yt_predict,y_test),accuracy_score(rt_pred,y_test),accuracy_score(y_pred_xgb,y_test)]
plt.bar(model_names,model_performance)
plt.xlabel("Model Names")
plt.ylabel("Model Accuracy")
plt.title("Model Name vs Model Accuracy")
plt.show()

# %%
#CONCLUSION:LOGISTIC REGRESSION,DECISON TREE CLASSFIER RANDOM FOREST CLASSFIER,XGBOOST HAVE DIFFERENT ACCURACY SO WE GO WITH RANDOM FOREST CLASSIFIER
#WHICH HAS HIGHEST ACCURACY AMONG OTHER TWO ALGORITHMS

# %%
#New User InPut Is taken
Pregnancies = int(input("Enter Pregnancies Count(1-10):-"))
Glucose = int(input("Enter Glucose Score:-"))
BloodPressure = int(input("Enter BloodPressure Value:-"))
SkinThickness = int(input("Enter SkinThinckness Value:-"))
Insulin = int(input("Enter Insulin Value:-"))
BMI  = float(input("Enter BMI Value:-"))
DiabetesPedigreeFunction = float(input("Enter DiabetesPedigreeFunction Value:-"))
Age = int(input("Enter Age of Person:-"))
# Out:
# Enter Pregnancies Count(1-10):-2
# Enter Glucose Score:-23
# Enter BloodPressure Value:-345
# Enter SkinThinckness Value:-12
# Enter Insulin Value:-87
# Enter BMI Value:-12.45
# Enter DiabetesPedigreeFunction Value:-1.34
# Enter Age of Person:-34

# %%
#This method predicted with the help of input features in form of 2d array for each person these nine input features are passed to model
predicted_output = rfc.predict([[Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
#SHOWING THE PREDICTED OUPTUT IN FORM OF 0 AND 1
predicted_output
# Out:
# array([0])

# %%
if predicted_output == 0:
  print("Person has No Diabetes")
else:
  print("Person has diabetes")
# Out:
# Person has No Diabetes

# %%
#CONCLUSION : WE HAVE RANDOM FOREST CLASSIFIER ALGORITHM TO TRAIN AND TEST DATA AND THEN WITH THE HELP OF PREDICT METHOD WE HAVE PREDICTED THAT PERSON HAS DIABETES OR NOT
